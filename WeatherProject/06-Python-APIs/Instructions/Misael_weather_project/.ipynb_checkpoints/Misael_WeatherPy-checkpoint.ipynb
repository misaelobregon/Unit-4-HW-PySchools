# %% [markdown]
# # WeatherPy
# ----
#
# #### Summary of Findings
# * Weather data from the Open Weather Map website shows that Max Temperatures closer to the equator (latitdue closer to "0") tend to increase, meaning temperatures are hotter closer to the equator (see "City Latitude vs. Max Temperature" for results).
#
# * Other weather patterns were less prominent in the data. That is to say that there does not appear to be a clear indication in the relationship between Humidity, Wind Speed, and much less for Cloudiness.
#
# * Future research may be done to find more prominent patterns in the latter results, for example, perhaps look at coastal cities vs. inland cities in relation to Latitude, Humidity and Wind Speed.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import citipy
import random
import json

# Import API key
from api_keys import api_key

#http://api.openweathermap.org/data/2.5/forecast?id={geo_id}&APPID={api_keys.py}

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "../output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Setting the url for weather api for cities by geographic coordinates
url = "https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&APPID={api_keys.py}"

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
#lngs
len(cities)
# Out:
# 645

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Performing weather check on cities using series of successive API calls


baseurl = "http://api.openweathermap.org/data/2.5/weather?"
print("Beginning Data Retrieval")
print("-----------------------------")

#print(f"Processing Record: {lat_lngs[cities]}")

# Get one of the posts
Row=[]
set_count = 1
record_count = 1
for city in cities:
    # Build query URL
    url = baseurl + "appid=" + api_key + "&q=" + city + "&units=imperial"
    response = requests.get(url).json()
    try:
        Row.append([response["name"],response["clouds"]['all'],response["sys"]['country'],response["dt"],response["main"]["humidity"],response["coord"]["lat"],response["coord"]["lon"],response["main"]["temp_max"],response["wind"]["speed"]])
        print(f"Processing Record {record_count} of Set {set_count} | {city}")
        if ((record_count ==50)&(set_count==1)) or ((record_count==49)&(set_count!=1)):
              record_count =0
              set_count +=1
        else: record_count +=1
    except KeyError:
        print('City not found. Skipping...')  
print("-----------------------------")
print("Data Retrieval Complete")     
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | avera
# Processing Record 2 of Set 1 | kachiry
# Processing Record 3 of Set 1 | srednekolymsk
# Processing Record 4 of Set 1 | kapaa
# Processing Record 5 of Set 1 | uvelskiy
# Processing Record 6 of Set 1 | new norfolk
# Processing Record 7 of Set 1 | punta arenas
# Processing Record 8 of Set 1 | dwarka
# Processing Record 9 of Set 1 | abu dhabi
# Processing Record 10 of Set 1 | hilo
# Processing Record 11 of Set 1 | pochutla
# Processing Record 12 of Set 1 | lebu
# City not found. Skipping...
# Processing Record 13 of Set 1 | saint-leu
# Processing Record 14 of Set 1 | pakxe
# Processing Record 15 of Set 1 | talnakh
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 16 of Set 1 | umm lajj
# Processing Record 17 of Set 1 | magway
# Processing Record 18 of Set 1 | upernavik
# Processing Record 19 of Set 1 | hithadhoo
# Processing Record 20 of Set 1 | witu
# Processing Record 21 of Set 1 | winsum
# Processing Record 22 of Set 1 | ornes
# Processing Record 23 of Set 1 | simbahan
# Processing Record 24 of Set 1 | cherskiy
# Processing Record 25 of Set 1 | albany
# Processing Record 26 of Set 1 | bourail
# City not found. Skipping...
# Processing Record 27 of Set 1 | yellowknife
# Processing Record 28 of Set 1 | ushuaia
# Processing Record 29 of Set 1 | kahului
# Processing Record 30 of Set 1 | tuktoyaktuk
# Processing Record 31 of Set 1 | norman wells
# Processing Record 32 of Set 1 | barinitas
# Processing Record 33 of Set 1 | evensk
# Processing Record 34 of Set 1 | cidreira
# Processing Record 35 of Set 1 | rawson
# Processing Record 36 of Set 1 | inhambane
# Processing Record 37 of Set 1 | saskylakh
# Processing Record 38 of Set 1 | bluff
# Processing Record 39 of Set 1 | coruripe
# City not found. Skipping...
# Processing Record 40 of Set 1 | rikitea
# Processing Record 41 of Set 1 | atuona
# Processing Record 42 of Set 1 | katsuura
# Processing Record 43 of Set 1 | balikpapan
# Processing Record 44 of Set 1 | sao miguel do araguaia
# Processing Record 45 of Set 1 | nanortalik
# Processing Record 46 of Set 1 | coos bay
# Processing Record 47 of Set 1 | busselton
# Processing Record 48 of Set 1 | mataura
# Processing Record 49 of Set 1 | vaini
# Processing Record 50 of Set 1 | butaritari
# Processing Record 0 of Set 2 | dasoguz
# Processing Record 1 of Set 2 | eunice
# City not found. Skipping...
# Processing Record 2 of Set 2 | ovre ardal
# Processing Record 3 of Set 2 | hervey bay
# Processing Record 4 of Set 2 | cape town
# Processing Record 5 of Set 2 | kibaha
# Processing Record 6 of Set 2 | noyabrsk
# Processing Record 7 of Set 2 | mar del plata
# Processing Record 8 of Set 2 | todos santos
# Processing Record 9 of Set 2 | somerset east
# Processing Record 10 of Set 2 | inuvik
# Processing Record 11 of Set 2 | slave lake
# Processing Record 12 of Set 2 | fairbanks
# Processing Record 13 of Set 2 | mednogorskiy
# Processing Record 14 of Set 2 | haines junction
# Processing Record 15 of Set 2 | hobart
# Processing Record 16 of Set 2 | mehamn
# Processing Record 17 of Set 2 | shimoda
# City not found. Skipping...
# Processing Record 18 of Set 2 | kaitangata
# Processing Record 19 of Set 2 | severo-kurilsk
# Processing Record 20 of Set 2 | east london
# Processing Record 21 of Set 2 | yashalta
# City not found. Skipping...
# Processing Record 22 of Set 2 | necochea
# Processing Record 23 of Set 2 | longyearbyen
# Processing Record 24 of Set 2 | taoudenni
# Processing Record 25 of Set 2 | xuanzhou
# Processing Record 26 of Set 2 | havre-saint-pierre
# Processing Record 27 of Set 2 | bandarbeyla
# Processing Record 28 of Set 2 | victoria
# Processing Record 29 of Set 2 | bambous virieux
# Processing Record 30 of Set 2 | sitka
# Processing Record 31 of Set 2 | matadi
# Processing Record 32 of Set 2 | ilulissat
# Processing Record 33 of Set 2 | bredasdorp
# Processing Record 34 of Set 2 | salamiyah
# Processing Record 35 of Set 2 | maryville
# Processing Record 36 of Set 2 | matiri
# Processing Record 37 of Set 2 | port alfred
# Processing Record 38 of Set 2 | saint-philippe
# Processing Record 39 of Set 2 | jamestown
# Processing Record 40 of Set 2 | miguel hidalgo
# Processing Record 41 of Set 2 | sorland
# Processing Record 42 of Set 2 | barrow
# Processing Record 43 of Set 2 | mayo
# Processing Record 44 of Set 2 | hami
# Processing Record 45 of Set 2 | huicheng
# Processing Record 46 of Set 2 | ostrovnoy
# City not found. Skipping...
# Processing Record 47 of Set 2 | sola
# City not found. Skipping...
# Processing Record 48 of Set 2 | sisimiut
# Processing Record 49 of Set 2 | atar
# Processing Record 0 of Set 3 | egvekinot
# Processing Record 1 of Set 3 | coromandel
# Processing Record 2 of Set 3 | boyolangu
# Processing Record 3 of Set 3 | shizunai
# Processing Record 4 of Set 3 | malibu
# Processing Record 5 of Set 3 | chingirlau
# Processing Record 6 of Set 3 | vila velha
# Processing Record 7 of Set 3 | margate
# Processing Record 8 of Set 3 | miyang
# Processing Record 9 of Set 3 | vostok
# Processing Record 10 of Set 3 | castro
# Processing Record 11 of Set 3 | ancud
# Processing Record 12 of Set 3 | hasaki
# Processing Record 13 of Set 3 | barcelos
# Processing Record 14 of Set 3 | madimba
# Processing Record 15 of Set 3 | joensuu
# Processing Record 16 of Set 3 | port hardy
# Processing Record 17 of Set 3 | fortuna
# Processing Record 18 of Set 3 | chuy
# City not found. Skipping...
# Processing Record 19 of Set 3 | boisar
# Processing Record 20 of Set 3 | fort-shevchenko
# Processing Record 21 of Set 3 | port elizabeth
# Processing Record 22 of Set 3 | penhold
# Processing Record 23 of Set 3 | kungsbacka
# Processing Record 24 of Set 3 | ixtapa
# Processing Record 25 of Set 3 | sur
# Processing Record 26 of Set 3 | bariadi
# Processing Record 27 of Set 3 | iskilip
# Processing Record 28 of Set 3 | miandrivazo
# Processing Record 29 of Set 3 | mattru
# Processing Record 30 of Set 3 | batemans bay
# Processing Record 31 of Set 3 | saint george
# Processing Record 32 of Set 3 | ponta do sol
# Processing Record 33 of Set 3 | saldanha
# City not found. Skipping...
# Processing Record 34 of Set 3 | severo-yeniseyskiy
# Processing Record 35 of Set 3 | tezu
# Processing Record 36 of Set 3 | george
# Processing Record 37 of Set 3 | hermanus
# Processing Record 38 of Set 3 | nikolskoye
# Processing Record 39 of Set 3 | banda aceh
# Processing Record 40 of Set 3 | luanda
# Processing Record 41 of Set 3 | bosaso
# Processing Record 42 of Set 3 | sao filipe
# Processing Record 43 of Set 3 | zelenogradsk
# Processing Record 44 of Set 3 | bonneville
# Processing Record 45 of Set 3 | boca do acre
# Processing Record 46 of Set 3 | eureka
# Processing Record 47 of Set 3 | iraquara
# Processing Record 48 of Set 3 | marawi
# Processing Record 49 of Set 3 | san policarpo
# Processing Record 0 of Set 4 | klaksvik
# Processing Record 1 of Set 4 | mizdah
# Processing Record 2 of Set 4 | saint peters
# Processing Record 3 of Set 4 | marsa matruh
# City not found. Skipping...
# Processing Record 4 of Set 4 | ust-maya
# City not found. Skipping...
# Processing Record 5 of Set 4 | nome
# Processing Record 6 of Set 4 | san lorenzo
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 7 of Set 4 | dunedin
# Processing Record 8 of Set 4 | vestmannaeyjar
# Processing Record 9 of Set 4 | cururupu
# Processing Record 10 of Set 4 | valparaiso
# Processing Record 11 of Set 4 | isangel
# City not found. Skipping...
# Processing Record 12 of Set 4 | mahebourg
# Processing Record 13 of Set 4 | khatanga
# Processing Record 14 of Set 4 | salina cruz
# Processing Record 15 of Set 4 | tuatapere
# Processing Record 16 of Set 4 | ape
# City not found. Skipping...
# Processing Record 17 of Set 4 | thompson
# City not found. Skipping...
# Processing Record 18 of Set 4 | college
# Processing Record 19 of Set 4 | male
# Processing Record 20 of Set 4 | iqaluit
# Processing Record 21 of Set 4 | mujiayingzi
# Processing Record 22 of Set 4 | nouadhibou
# Processing Record 23 of Set 4 | zyryanka
# Processing Record 24 of Set 4 | portland
# Processing Record 25 of Set 4 | esperance
# Processing Record 26 of Set 4 | muroto
# Processing Record 27 of Set 4 | avarua
# Processing Record 28 of Set 4 | bethel
# Processing Record 29 of Set 4 | caravelas
# Processing Record 30 of Set 4 | geraldton
# Processing Record 31 of Set 4 | rockingham
# Processing Record 32 of Set 4 | carroll
# Processing Record 33 of Set 4 | pacific grove
# Processing Record 34 of Set 4 | aras
# Processing Record 35 of Set 4 | tiksi
# Processing Record 36 of Set 4 | viedma
# Processing Record 37 of Set 4 | chokurdakh
# Processing Record 38 of Set 4 | izazi
# Processing Record 39 of Set 4 | rocha
# Processing Record 40 of Set 4 | whitehorse
# Processing Record 41 of Set 4 | paracuru
# City not found. Skipping...
# Processing Record 42 of Set 4 | sierra vista
# Processing Record 43 of Set 4 | chalus
# Processing Record 44 of Set 4 | noumea
# Processing Record 45 of Set 4 | port hawkesbury
# Processing Record 46 of Set 4 | lompoc
# Processing Record 47 of Set 4 | puerto ayora
# Processing Record 48 of Set 4 | vigia
# Processing Record 49 of Set 4 | nokaneng
# Processing Record 0 of Set 5 | tapejara
# Processing Record 1 of Set 5 | batagay
# Processing Record 2 of Set 5 | anito
# Processing Record 3 of Set 5 | comodoro rivadavia
# City not found. Skipping...
# Processing Record 4 of Set 5 | kamien pomorski
# Processing Record 5 of Set 5 | lagoa
# Processing Record 6 of Set 5 | vallenar
# Processing Record 7 of Set 5 | deep river
# Processing Record 8 of Set 5 | corinto
# City not found. Skipping...
# Processing Record 9 of Set 5 | marmaris
# Processing Record 10 of Set 5 | carnarvon
# Processing Record 11 of Set 5 | acajutla
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 12 of Set 5 | platanos
# City not found. Skipping...
# Processing Record 13 of Set 5 | bitung
# Processing Record 14 of Set 5 | bahia blanca
# Processing Record 15 of Set 5 | peniche
# Processing Record 16 of Set 5 | lorengau
# Processing Record 17 of Set 5 | darab
# City not found. Skipping...
# Processing Record 18 of Set 5 | maniitsoq
# Processing Record 19 of Set 5 | manggar
# Processing Record 20 of Set 5 | krasnoarmeysk
# Processing Record 21 of Set 5 | tamandare
# Processing Record 22 of Set 5 | kavieng
# Processing Record 23 of Set 5 | dikson
# Processing Record 24 of Set 5 | pujili
# Processing Record 25 of Set 5 | ambon
# Processing Record 26 of Set 5 | qaanaaq
# Processing Record 27 of Set 5 | yeppoon
# Processing Record 28 of Set 5 | goure
# Processing Record 29 of Set 5 | mugur-aksy
# Processing Record 30 of Set 5 | mishkino
# Processing Record 31 of Set 5 | biak
# City not found. Skipping...
# Processing Record 32 of Set 5 | sydney mines
# City not found. Skipping...
# Processing Record 33 of Set 5 | tilichiki
# Processing Record 34 of Set 5 | rovenki
# Processing Record 35 of Set 5 | baturaja
# Processing Record 36 of Set 5 | arraial do cabo
# Processing Record 37 of Set 5 | yumen
# Processing Record 38 of Set 5 | pimentel
# Processing Record 39 of Set 5 | general cepeda
# Processing Record 40 of Set 5 | mlonggo
# Processing Record 41 of Set 5 | haapiti
# Processing Record 42 of Set 5 | okhotsk
# Processing Record 43 of Set 5 | redlands
# Processing Record 44 of Set 5 | cayenne
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 45 of Set 5 | goba
# Processing Record 46 of Set 5 | guerrero negro
# Processing Record 47 of Set 5 | barcarena
# Processing Record 48 of Set 5 | honningsvag
# Processing Record 49 of Set 5 | mount gambier
# Processing Record 0 of Set 6 | itaqui
# Processing Record 1 of Set 6 | bad laer
# Processing Record 2 of Set 6 | grand island
# Processing Record 3 of Set 6 | bathsheba
# Processing Record 4 of Set 6 | husavik
# Processing Record 5 of Set 6 | kruisfontein
# Processing Record 6 of Set 6 | maua
# Processing Record 7 of Set 6 | ipixuna
# Processing Record 8 of Set 6 | pevek
# Processing Record 9 of Set 6 | georgetown
# Processing Record 10 of Set 6 | marshall
# Processing Record 11 of Set 6 | stepnyak
# Processing Record 12 of Set 6 | taltal
# Processing Record 13 of Set 6 | qinzhou
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 14 of Set 6 | tsiroanomandidy
# Processing Record 15 of Set 6 | tura
# Processing Record 16 of Set 6 | saint-pierre
# Processing Record 17 of Set 6 | makushino
# Processing Record 18 of Set 6 | belmonte
# Processing Record 19 of Set 6 | airai
# Processing Record 20 of Set 6 | arica
# Processing Record 21 of Set 6 | gainesville
# Processing Record 22 of Set 6 | provideniya
# Processing Record 23 of Set 6 | zhanaozen
# Processing Record 24 of Set 6 | sinnamary
# Processing Record 25 of Set 6 | grindavik
# Processing Record 26 of Set 6 | krasnoye
# Processing Record 27 of Set 6 | abrau-dyurso
# Processing Record 28 of Set 6 | tombouctou
# Processing Record 29 of Set 6 | cabo san lucas
# Processing Record 30 of Set 6 | yulara
# City not found. Skipping...
# Processing Record 31 of Set 6 | kaupanger
# City not found. Skipping...
# Processing Record 32 of Set 6 | avallon
# Processing Record 33 of Set 6 | perama
# Processing Record 34 of Set 6 | dekar
# Processing Record 35 of Set 6 | ghanzi
# City not found. Skipping...
# Processing Record 36 of Set 6 | clyde river
# Processing Record 37 of Set 6 | pocone
# Processing Record 38 of Set 6 | grand gaube
# Processing Record 39 of Set 6 | flin flon
# Processing Record 40 of Set 6 | kodiak
# City not found. Skipping...
# Processing Record 41 of Set 6 | pangody
# Processing Record 42 of Set 6 | namibe
# Processing Record 43 of Set 6 | vanimo
# Processing Record 44 of Set 6 | rundu
# City not found. Skipping...
# Processing Record 45 of Set 6 | alofi
# Processing Record 46 of Set 6 | mahibadhoo
# Processing Record 47 of Set 6 | lubumbashi
# Processing Record 48 of Set 6 | anadyr
# Processing Record 49 of Set 6 | kavaratti
# Processing Record 0 of Set 7 | souillac
# Processing Record 1 of Set 7 | loding
# Processing Record 2 of Set 7 | kabarnet
# Processing Record 3 of Set 7 | skovorodino
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 4 of Set 7 | caconda
# Processing Record 5 of Set 7 | touros
# Processing Record 6 of Set 7 | jilin
# Processing Record 7 of Set 7 | bolobo
# Processing Record 8 of Set 7 | bundaberg
# Processing Record 9 of Set 7 | ocote paulino
# Processing Record 10 of Set 7 | torbay
# Processing Record 11 of Set 7 | ketchikan
# Processing Record 12 of Set 7 | astoria
# Processing Record 13 of Set 7 | micheweni
# Processing Record 14 of Set 7 | mudgee
# Processing Record 15 of Set 7 | moss vale
# City not found. Skipping...
# Processing Record 16 of Set 7 | campina verde
# Processing Record 17 of Set 7 | alice springs
# Processing Record 18 of Set 7 | salinopolis
# Processing Record 19 of Set 7 | rafaela
# Processing Record 20 of Set 7 | yurla
# Processing Record 21 of Set 7 | tazovskiy
# City not found. Skipping...
# Processing Record 22 of Set 7 | nacala
# Processing Record 23 of Set 7 | takaka
# City not found. Skipping...
# Processing Record 24 of Set 7 | mapiripan
# Processing Record 25 of Set 7 | kloulklubed
# Processing Record 26 of Set 7 | jinxiang
# Processing Record 27 of Set 7 | iskateley
# Processing Record 28 of Set 7 | cristalina
# Processing Record 29 of Set 7 | kenai
# Processing Record 30 of Set 7 | waipawa
# Processing Record 31 of Set 7 | galle
# Processing Record 32 of Set 7 | broken hill
# Processing Record 33 of Set 7 | shahi
# Processing Record 34 of Set 7 | hualmay
# City not found. Skipping...
# Processing Record 35 of Set 7 | santo antonio da platina
# Processing Record 36 of Set 7 | hay river
# Processing Record 37 of Set 7 | kurilsk
# Processing Record 38 of Set 7 | gagnoa
# Processing Record 39 of Set 7 | lisakovsk
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 40 of Set 7 | morehead
# Processing Record 41 of Set 7 | narsaq
# Processing Record 42 of Set 7 | palmer
# Processing Record 43 of Set 7 | sorong
# Processing Record 44 of Set 7 | oxapampa
# Processing Record 45 of Set 7 | tasiilaq
# Processing Record 46 of Set 7 | kirakira
# Processing Record 47 of Set 7 | syracuse
# Processing Record 48 of Set 7 | arman
# Processing Record 49 of Set 7 | marzuq
# Processing Record 0 of Set 8 | kodinsk
# City not found. Skipping...
# Processing Record 1 of Set 8 | kovdor
# Processing Record 2 of Set 8 | onguday
# Processing Record 3 of Set 8 | prince rupert
# Processing Record 4 of Set 8 | nattarasankottai
# Processing Record 5 of Set 8 | yurimaguas
# Processing Record 6 of Set 8 | majene
# Processing Record 7 of Set 8 | umm kaddadah
# Processing Record 8 of Set 8 | axim
# Processing Record 9 of Set 8 | faanui
# Processing Record 10 of Set 8 | beroroha
# Processing Record 11 of Set 8 | hakkari
# Processing Record 12 of Set 8 | sao joao da barra
# Processing Record 13 of Set 8 | port shepstone
# Processing Record 14 of Set 8 | ossora
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 15 of Set 8 | le port
# Processing Record 16 of Set 8 | qaqortoq
# Processing Record 17 of Set 8 | buin
# Processing Record 18 of Set 8 | gazanjyk
# City not found. Skipping...
# Processing Record 19 of Set 8 | luderitz
# Processing Record 20 of Set 8 | sao jose de ribamar
# Processing Record 21 of Set 8 | buala
# Processing Record 22 of Set 8 | abnub
# Processing Record 23 of Set 8 | camabatela
# Processing Record 24 of Set 8 | angoche
# Processing Record 25 of Set 8 | novobelokatay
# Processing Record 26 of Set 8 | davila
# Processing Record 27 of Set 8 | maceio
# Processing Record 28 of Set 8 | bara
# Processing Record 29 of Set 8 | nynashamn
# Processing Record 30 of Set 8 | orocue
# Processing Record 31 of Set 8 | agirish
# Processing Record 32 of Set 8 | rapid valley
# Processing Record 33 of Set 8 | asyut
# Processing Record 34 of Set 8 | vilyuysk
# Processing Record 35 of Set 8 | qeshm
# Processing Record 36 of Set 8 | acapulco
# Processing Record 37 of Set 8 | san juan
# Processing Record 38 of Set 8 | neubrandenburg
# Processing Record 39 of Set 8 | aklavik
# Processing Record 40 of Set 8 | qaracala
# Processing Record 41 of Set 8 | takestan
# Processing Record 42 of Set 8 | ust-kan
# Processing Record 43 of Set 8 | nabire
# Processing Record 44 of Set 8 | taupo
# City not found. Skipping...
# Processing Record 45 of Set 8 | zhumadian
# Processing Record 46 of Set 8 | beloha
# Processing Record 47 of Set 8 | khani
# Processing Record 48 of Set 8 | sept-iles
# Processing Record 49 of Set 8 | bani
# Processing Record 0 of Set 9 | nago
# Processing Record 1 of Set 9 | nageshwari
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 2 of Set 9 | zhirnovsk
# Processing Record 3 of Set 9 | marovoay
# Processing Record 4 of Set 9 | ocara
# Processing Record 5 of Set 9 | nova olinda do norte
# Processing Record 6 of Set 9 | los llanos de aridane
# City not found. Skipping...
# Processing Record 7 of Set 9 | santa cruz
# Processing Record 8 of Set 9 | lata
# Processing Record 9 of Set 9 | vila do maio
# City not found. Skipping...
# Processing Record 10 of Set 9 | ushtobe
# Processing Record 11 of Set 9 | lyskovo
# Processing Record 12 of Set 9 | ribeira grande
# Processing Record 13 of Set 9 | harper
# Processing Record 14 of Set 9 | chimbote
# Processing Record 15 of Set 9 | gold coast
# Processing Record 16 of Set 9 | guarapari
# Processing Record 17 of Set 9 | galiakot
# Processing Record 18 of Set 9 | phalaborwa
# Processing Record 19 of Set 9 | suarez
# City not found. Skipping...
# Processing Record 20 of Set 9 | cortez
# Processing Record 21 of Set 9 | gornopravdinsk
# Processing Record 22 of Set 9 | ranong
# Processing Record 23 of Set 9 | stromness
# Processing Record 24 of Set 9 | lakefield
# Processing Record 25 of Set 9 | shebunino
# Processing Record 26 of Set 9 | seoul
# Processing Record 27 of Set 9 | ifanadiana
# Processing Record 28 of Set 9 | zhigansk
# Processing Record 29 of Set 9 | sarangani
# Processing Record 30 of Set 9 | panzhihua
# Processing Record 31 of Set 9 | leningradskiy
# Processing Record 32 of Set 9 | monterey
# Processing Record 33 of Set 9 | pontes e lacerda
# Processing Record 34 of Set 9 | thinadhoo
# Processing Record 35 of Set 9 | madang
# Processing Record 36 of Set 9 | lac-au-saumon
# Processing Record 37 of Set 9 | altay
# Processing Record 38 of Set 9 | wenling
# Processing Record 39 of Set 9 | borba
# Processing Record 40 of Set 9 | meaford
# Processing Record 41 of Set 9 | mountain home
# Processing Record 42 of Set 9 | nantucket
# Processing Record 43 of Set 9 | gurupi
# Processing Record 44 of Set 9 | kerchevskiy
# Processing Record 45 of Set 9 | pingdingshan
# Processing Record 46 of Set 9 | alta floresta
# Processing Record 47 of Set 9 | hanzhong
# Processing Record 48 of Set 9 | san patricio
# Processing Record 49 of Set 9 | cap-aux-meules
# Processing Record 0 of Set 10 | sioux lookout
# Processing Record 1 of Set 10 | quatre cocos
# Processing Record 2 of Set 10 | coquimbo
# Processing Record 3 of Set 10 | ostersund
# Processing Record 4 of Set 10 | gat
# Processing Record 5 of Set 10 | coihaique
# Processing Record 6 of Set 10 | taklisah
# Processing Record 7 of Set 10 | pedernales
# Processing Record 8 of Set 10 | bandar
# Processing Record 9 of Set 10 | rock sound
# Processing Record 10 of Set 10 | atambua
# Processing Record 11 of Set 10 | illapel
# Processing Record 12 of Set 10 | waraseoni
# Processing Record 13 of Set 10 | codrington
# Processing Record 14 of Set 10 | uaua
# Processing Record 15 of Set 10 | tecolutilla
# Processing Record 16 of Set 10 | bam
# Processing Record 17 of Set 10 | kangaba
# Processing Record 18 of Set 10 | canyon
# Processing Record 19 of Set 10 | baykit
# Processing Record 20 of Set 10 | mokrous
# Processing Record 21 of Set 10 | usinsk
# Processing Record 22 of Set 10 | erenhot
# Processing Record 23 of Set 10 | nishihara
# Processing Record 24 of Set 10 | hofn
# Processing Record 25 of Set 10 | qujing
# Processing Record 26 of Set 10 | pilar
# Processing Record 27 of Set 10 | charters towers
# Processing Record 28 of Set 10 | saint-maximin-la-sainte-baume
# Processing Record 29 of Set 10 | pangnirtung
# Processing Record 30 of Set 10 | barra velha
# Processing Record 31 of Set 10 | polson
# Processing Record 32 of Set 10 | prado
# Processing Record 33 of Set 10 | sibolga
# Processing Record 34 of Set 10 | kasempa
# Processing Record 35 of Set 10 | jerome
# Processing Record 36 of Set 10 | manta
# Processing Record 37 of Set 10 | kaeo
# Processing Record 38 of Set 10 | padang
# Processing Record 39 of Set 10 | jiangyou
# Processing Record 40 of Set 10 | san ramon
# Processing Record 41 of Set 10 | fort nelson
# City not found. Skipping...
# Processing Record 42 of Set 10 | staryy nadym
# Processing Record 43 of Set 10 | lengshuitan
# City not found. Skipping...
# Processing Record 44 of Set 10 | fonte boa
# Processing Record 45 of Set 10 | karratha
# Processing Record 46 of Set 10 | dakar
# Processing Record 47 of Set 10 | fare
# Processing Record 48 of Set 10 | canton
# City not found. Skipping...
# Processing Record 49 of Set 10 | peachland
# Processing Record 0 of Set 11 | takoradi
# Processing Record 1 of Set 11 | te anau
# Processing Record 2 of Set 11 | presidente medici
# Processing Record 3 of Set 11 | half moon bay
# Processing Record 4 of Set 11 | naze
# Processing Record 5 of Set 11 | hokitika
# Processing Record 6 of Set 11 | constitucion
# Processing Record 7 of Set 11 | hovd
# Processing Record 8 of Set 11 | zverinogolovskoye
# Processing Record 9 of Set 11 | stralsund
# Processing Record 10 of Set 11 | santa isabel do rio negro
# Processing Record 11 of Set 11 | yar-sale
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 12 of Set 11 | pulandian
# Processing Record 13 of Set 11 | sindor
# Processing Record 14 of Set 11 | nizza monferrato
# Processing Record 15 of Set 11 | verkh-usugli
# Processing Record 16 of Set 11 | darhan
# Processing Record 17 of Set 11 | kaduna
# Processing Record 18 of Set 11 | barendrecht
# Processing Record 19 of Set 11 | richards bay
# Processing Record 20 of Set 11 | pachino
# Processing Record 21 of Set 11 | mina
# Processing Record 22 of Set 11 | rantepao
# Processing Record 23 of Set 11 | aschersleben
# Processing Record 24 of Set 11 | hibbing
# Processing Record 25 of Set 11 | guasdualito
# Processing Record 26 of Set 11 | laguna
# Processing Record 27 of Set 11 | raudeberg
# Processing Record 28 of Set 11 | hit
# Processing Record 29 of Set 11 | aksaray
# Processing Record 30 of Set 11 | les cayes
# Processing Record 31 of Set 11 | gribanovskiy
# Processing Record 32 of Set 11 | santa marta
# Processing Record 33 of Set 11 | hobyo
# Processing Record 34 of Set 11 | ylivieska
# Processing Record 35 of Set 11 | ayan
# Processing Record 36 of Set 11 | babu
# Processing Record 37 of Set 11 | broome
# Processing Record 38 of Set 11 | moorhead
# Processing Record 39 of Set 11 | lucea
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 40 of Set 11 | xiaoshi
# Processing Record 41 of Set 11 | emerald
# Processing Record 42 of Set 11 | douglas
# Processing Record 43 of Set 11 | chicama
# Processing Record 44 of Set 11 | atbasar
# Processing Record 45 of Set 11 | barra do garcas
# Processing Record 46 of Set 11 | nyurba
# Processing Record 47 of Set 11 | pisco
# Processing Record 48 of Set 11 | porbandar
# Processing Record 49 of Set 11 | winnemucca
# Processing Record 0 of Set 12 | kemin
# Processing Record 1 of Set 12 | saint-francois
# Processing Record 2 of Set 12 | road town
# Processing Record 3 of Set 12 | freeport
# Processing Record 4 of Set 12 | molde
# Processing Record 5 of Set 12 | luba
# Processing Record 6 of Set 12 | mantua
# Processing Record 7 of Set 12 | luau
# Processing Record 8 of Set 12 | wuwei
# Processing Record 9 of Set 12 | miles city
# Processing Record 10 of Set 12 | luwuk
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 11 of Set 12 | putina
# Processing Record 12 of Set 12 | sorata
# Processing Record 13 of Set 12 | gidam
# Processing Record 14 of Set 12 | kyshtovka
# Processing Record 15 of Set 12 | westport
# Processing Record 16 of Set 12 | ati
# Processing Record 17 of Set 12 | olinda
# Processing Record 18 of Set 12 | athabasca
# Processing Record 19 of Set 12 | newport
# City not found. Skipping...
# Processing Record 20 of Set 12 | giyani
# Processing Record 21 of Set 12 | shanghai
# Processing Record 22 of Set 12 | barsuki
# Processing Record 23 of Set 12 | shahreza
# Processing Record 24 of Set 12 | berlevag
# City not found. Skipping...
# Processing Record 25 of Set 12 | dandong
# Processing Record 26 of Set 12 | colon
# Processing Record 27 of Set 12 | lavrentiya
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
df =pd.DataFrame(Row,columns=("City", "Cloudiness", "Country","Date","Humidity","Lat","Lng","Max Temp","Wind Speed"))
df.head()
# Out:
#             City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0          Avera           1      US  1563660458        49  33.19  -82.53
# 1        Kachiry           3      KZ  1563660458        77  53.07   76.10
# 2  Srednekolymsk         100      RU  1563660459        52  67.46  153.71
# 3          Kapaa          90      US  1563660459        66  22.08 -159.32
# 4       Uvelskiy         100      RU  1563660459        93  54.44   61.36
#
#    Max Temp  Wind Speed
# 0     93.20        5.82
# 1     66.76        5.01
# 2     51.64       11.45
# 3     86.00       12.75
# 4     66.04       11.83

# %%
df.to_csv(output_data_file)
df.shape
# Out:
# (578, 9)

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
fig,temp = plt.subplots(figsize = (6,4))
temp.scatter(x=df["Lat"],y=df["Max Temp"],facecolor ="teal",edgecolor="k",alpha = 0.85,linewidth =1)
date =time.strftime("%m/%d/%Y")
plt.title(f"City Latitude vs. Max Temperature [{date}]")
temp.set_xlabel("Latitude")
temp.set_ylabel("Max Temperature (F)")
plt.grid()
plt.tight_layout()
plt.savefig("../Images/temp_lat.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
fig,humid = plt.subplots(figsize = (6,4))
humid.scatter(x=df["Lat"],y=df["Humidity"],facecolor ="teal",edgecolor="k",alpha = 0.85,linewidth =1)
date =time.strftime("%m/%d/%Y")
plt.title(f"City Latitude vs. Humidity [{date}]")
humid.set_xlabel("Latitude")
humid.set_ylabel("Humidity (%)")
plt.grid()
plt.tight_layout()
plt.savefig("../Images/humid_lat.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
fig,cloud = plt.subplots(figsize = (6,4))
cloud.scatter(x=df["Lat"],y=df["Cloudiness"],facecolor ="teal",edgecolor="k",alpha = 0.85,linewidth =1)
date =time.strftime("%m/%d/%Y")
plt.title(f"City Latitude vs. Cloudiness [{date}]")
cloud.set_xlabel("Latitude")
cloud.set_ylabel("Cloudiness (%)")
plt.grid()
plt.tight_layout()
plt.savefig("../Images/cloud_lat.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
fig,wind = plt.subplots(figsize = (6,4))
wind.scatter(x=df["Lat"],y=df["Wind Speed"],facecolor ="teal",edgecolor="k",alpha = 0.85,linewidth =1)
date =time.strftime("%m/%d/%Y")
plt.title(f"City Latitude vs. Wind Speed [{date}]")
wind.set_xlabel("Latitude")
wind.set_ylabel("Wind Speed (mph)")
plt.grid()
plt.tight_layout()
plt.savefig("../Images/wind_lat.png")
plt.show()
